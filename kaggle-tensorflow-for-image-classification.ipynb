# %% [markdown]
# # Training deep learning models for image classification of flood events

# %% [markdown]
# ### Import modules

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Define main training parameters

# %%
params = {
    'data': '../input/flood-images/sgkf-8-1-1',
    'epochs': 25,
    'imgsz': 640,
    'batch': 32,
    'device': [0, 1],
    'learning_rate': 0.0001,
}

# Define image dimensions and batch size
img_height, img_width = 640, 640 # 480, 854

# %% [markdown]
# ### Enable GPU strategy for tensorflow model training

# %%
# Check if GPU is available
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("GPU is available.")
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
else:
    print("GPU not found. Using CPU.")
    
# Define mirrored strategy for GPU training
strategy = tf.distribute.MirroredStrategy()
# Out:
# GPU is available.

# %% [markdown]
# ### Define utility functions

# %%
def print_evaluation(model, train_generator, test_generator, val_generator):

    # Evaluate Model
    print("\n * Evaluation for Model 1 (Simple Convolutional Neural Network (CNN)):")

    predictions = model.predict(train_generator)
    y_pred = (predictions > 0.5).astype(int)
    print('\n * Confusion_matrix (TRAIN):')
    print(confusion_matrix(train_generator.classes, y_pred))
    print('\n * Classification_report (TRAIN):')
    print(classification_report(train_generator.classes, y_pred))

    predictions = model.predict(test_generator)
    y_pred = (predictions > 0.5).astype(int)
    print('\n * Confusion_matrix (TEST):')
    print(confusion_matrix(test_generator.classes, y_pred))
    print('\n * Classification_report (TEST):')
    print(classification_report(test_generator.classes, y_pred))

    predictions = model.predict(val_generator)
    y_pred = (predictions > 0.5).astype(int)
    print('\n * Confusion_matrix (VAL):')
    print(confusion_matrix(val_generator.classes, y_pred))
    print('\n * Classification_report (VAL):')
    print(classification_report(val_generator.classes, y_pred))
    
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

def plot_evaluation(model):
    # Plot training history for accuracy
    plt.plot(model.history['accuracy'], label='Train Accuracy')
    plt.plot(model.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    # Plot training history for loss
    plt.plot(model.history['loss'], label='Train Loss')
    plt.plot(model.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# ---
# ## Training and evaluation of the models

# %% [markdown]
# ### Simple Convolutional Neural Network (CNN)

# %%
checkpoint_filepath = 'results/best_model_cnn.h5'
custom_learning_rate = 0.000002

# Define data generators for training and testing sets
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator_shuffle = train_datagen.flow_from_directory(
    params['data'] + '/train',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=True,
)

train_generator = train_datagen.flow_from_directory(
    params['data'] + '/train',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

test_generator = test_datagen.flow_from_directory(
    params['data'] + '/test',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

val_generator = val_datagen.flow_from_directory(
    params['data'] + '/val',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

with strategy.scope():
    # Model 1: Simple Convolutional Neural Network (CNN)
    model1 = models.Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])

    # Create an optimizer with the custom learning rate
    custom_optimizer = Adam(learning_rate=custom_learning_rate)

    # Define a ModelCheckpoint callback to save the best model
    model_checkpoint_callback = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_best_only=True,
        monitor='val_accuracy',  # You can change this to 'val_accuracy' or another metric
        mode='max',          # Set to 'max' if monitoring accuracy, 'min' if monitoring loss
        verbose=1
    )

    # Compile the model with the custom optimizer
    model1.compile(optimizer=custom_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    fitted_model1 = model1.fit(train_generator_shuffle, epochs=params['epochs'], validation_data=test_generator, callbacks=[model_checkpoint_callback])

    # Load the best model from the saved checkpoint file
    model1 = models.load_model(checkpoint_filepath)
   
    # Print model evaluation
    print_evaluation(model1, train_generator, test_generator, val_generator)
    
    # Print model evaluation
    plot_evaluation(fitted_model1)
# Out:
# Found 791 images belonging to 2 classes.
# Found 791 images belonging to 2 classes.
# Found 114 images belonging to 2 classes.
# Found 95 images belonging to 2 classes.
# Epoch 1/25
# 25/25 [==============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.6195
# Epoch 1: val_accuracy improved from -inf to 0.67544, saving model to results/best_model_cnn.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 25s 889ms/step - loss: 0.6345 - accuracy: 0.6195 - val_loss: 0.6175 - val_accuracy: 0.6754
# Epoch 2/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4852 - accuracy: 0.8521
# Epoch 2: val_accuracy improved from 0.67544 to 0.82456, saving model to results/best_model_cnn.h5
# 25/25 [==============================] - 23s 943ms/step - loss: 0.4852 - accuracy: 0.8521 - val_loss: 0.5954 - val_accuracy: 0.8246
# Epoch 3/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4242 - accuracy: 0.8369
# Epoch 3: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 608ms/step - loss: 0.4242 - accuracy: 0.8369 - val_loss: 0.6083 - val_accuracy: 0.5000
# Epoch 4/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3602 - accuracy: 0.8938
# Epoch 4: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 601ms/step - loss: 0.3602 - accuracy: 0.8938 - val_loss: 0.5679 - val_accuracy: 0.8070
# Epoch 5/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.9267
# Epoch 5: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 603ms/step - loss: 0.3112 - accuracy: 0.9267 - val_loss: 0.5550 - val_accuracy: 0.8070
# Epoch 6/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.9216
# Epoch 6: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 601ms/step - loss: 0.2886 - accuracy: 0.9216 - val_loss: 0.5441 - val_accuracy: 0.7193
# Epoch 7/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.9507
# Epoch 7: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 16s 613ms/step - loss: 0.2524 - accuracy: 0.9507 - val_loss: 0.5254 - val_accuracy: 0.8070
# Epoch 8/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9570
# Epoch 8: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 610ms/step - loss: 0.2329 - accuracy: 0.9570 - val_loss: 0.5180 - val_accuracy: 0.8070
# Epoch 9/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9583
# Epoch 9: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 606ms/step - loss: 0.2157 - accuracy: 0.9583 - val_loss: 0.5206 - val_accuracy: 0.7895
# Epoch 10/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9570
# Epoch 10: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 604ms/step - loss: 0.2022 - accuracy: 0.9570 - val_loss: 0.5081 - val_accuracy: 0.7982
# Epoch 11/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9595
# Epoch 11: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 16s 614ms/step - loss: 0.1883 - accuracy: 0.9595 - val_loss: 0.4937 - val_accuracy: 0.8158
# Epoch 12/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9583
# Epoch 12: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 608ms/step - loss: 0.1792 - accuracy: 0.9583 - val_loss: 0.5102 - val_accuracy: 0.7632
# Epoch 13/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9621
# Epoch 13: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 606ms/step - loss: 0.1626 - accuracy: 0.9621 - val_loss: 0.5049 - val_accuracy: 0.7719
# Epoch 14/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9684
# Epoch 14: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 599ms/step - loss: 0.1559 - accuracy: 0.9684 - val_loss: 0.4793 - val_accuracy: 0.8246
# Epoch 15/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9659
# Epoch 15: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 608ms/step - loss: 0.1484 - accuracy: 0.9659 - val_loss: 0.4855 - val_accuracy: 0.7807
# Epoch 16/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9697
# Epoch 16: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 15s 601ms/step - loss: 0.1396 - accuracy: 0.9697 - val_loss: 0.4774 - val_accuracy: 0.8158
# Epoch 17/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9709
# Epoch 17: val_accuracy did not improve from 0.82456
# 25/25 [==============================] - 16s 616ms/step - loss: 0.1332 - accuracy: 0.9709 - val_loss: 0.4789 - val_accuracy: 0.7719
# Epoch 18/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9735
# Epoch 18: val_accuracy improved from 0.82456 to 0.85088, saving model to results/best_model_cnn.h5
# 25/25 [==============================] - 22s 885ms/step - loss: 0.1268 - accuracy: 0.9735 - val_loss: 0.4629 - val_accuracy: 0.8509
# Epoch 19/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9747
# Epoch 19: val_accuracy did not improve from 0.85088
# 25/25 [==============================] - 15s 611ms/step - loss: 0.1207 - accuracy: 0.9747 - val_loss: 0.4799 - val_accuracy: 0.7719
# Epoch 20/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9747
# Epoch 20: val_accuracy did not improve from 0.85088
# 25/25 [==============================] - 15s 603ms/step - loss: 0.1146 - accuracy: 0.9747 - val_loss: 0.4698 - val_accuracy: 0.7807
# Epoch 21/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9772
# Epoch 21: val_accuracy did not improve from 0.85088
# 25/25 [==============================] - 16s 630ms/step - loss: 0.1105 - accuracy: 0.9772 - val_loss: 0.4793 - val_accuracy: 0.7807
# Epoch 22/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9798
# Epoch 22: val_accuracy did not improve from 0.85088
# 25/25 [==============================] - 15s 609ms/step - loss: 0.1064 - accuracy: 0.9798 - val_loss: 0.4609 - val_accuracy: 0.7895
# Epoch 23/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9836
# Epoch 23: val_accuracy did not improve from 0.85088
# 25/25 [==============================] - 16s 613ms/step - loss: 0.1027 - accuracy: 0.9836 - val_loss: 0.4779 - val_accuracy: 0.7719
# Epoch 24/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9810
# Epoch 24: val_accuracy did not improve from 0.85088
# 25/25 [==============================] - 15s 619ms/step - loss: 0.1011 - accuracy: 0.9810 - val_loss: 0.4568 - val_accuracy: 0.8333
# Epoch 25/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9848
# Epoch 25: val_accuracy did not improve from 0.85088
# 25/25 [==============================] - 15s 612ms/step - loss: 0.0940 - accuracy: 0.9848 - val_loss: 0.4488 - val_accuracy: 0.8246
#
#  * Evaluation for Model 1 (Simple Convolutional Neural Network (CNN)):
# 25/25 [==============================] - 13s 481ms/step
#
#  * Confusion_matrix (TRAIN):
# [[383  11]
#  [  7 390]]
#
#  * Classification_report (TRAIN):
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       394
#            1       0.97      0.98      0.98       397
#
#     accuracy                           0.98       791
#    macro avg       0.98      0.98      0.98       791
# weighted avg       0.98      0.98      0.98       791
#
# 4/4 [==============================] - 2s 398ms/step
#
#  * Confusion_matrix (TEST):
# [[47 11]
#  [ 6 50]]
#
#  * Classification_report (TEST):
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85        58
#            1       0.82      0.89      0.85        56
#
#     accuracy                           0.85       114
#    macro avg       0.85      0.85      0.85       114
# weighted avg       0.85      0.85      0.85       114
#
# 3/3 [==============================] - 2s 498ms/step
#
#  * Confusion_matrix (VAL):
# [[37 11]
#  [ 4 43]]
#
#  * Classification_report (VAL):
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83        48
#            1       0.80      0.91      0.85        47
#
#     accuracy                           0.84        95
#    macro avg       0.85      0.84      0.84        95
# weighted avg       0.85      0.84      0.84        95

# %% [markdown]
# ### Transfer Learning with MobileNetV2

# %%
checkpoint_filepath = 'results/best_model_mobilenetv2.h5'
custom_learning_rate = 0.000002

# Define data generators for training and testing sets
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator_shuffle = train_datagen.flow_from_directory(
    params['data'] + '/train',
    target_size=(224, 224),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=True,
)

train_generator = train_datagen.flow_from_directory(
    params['data'] + '/train',
    target_size=(224, 224),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

test_generator = test_datagen.flow_from_directory(
    params['data'] + '/test',
    target_size=(224, 224),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

val_generator = val_datagen.flow_from_directory(
    params['data'] + '/val',
    target_size=(224, 224),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

with strategy.scope():
    # Model 2: Transfer Learning with MobileNetV2
    base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3),
                                                   include_top=False,
                                                   weights='imagenet')

    model2 = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(1, activation='sigmoid')
    ])

    # Create an optimizer with the custom learning rate
    custom_optimizer = Adam(learning_rate=custom_learning_rate)

    # Define a ModelCheckpoint callback to save the best model
    model_checkpoint_callback = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_best_only=True,
        monitor='val_accuracy',  # You can change this to 'val_accuracy' or another metric
        mode='max',          # Set to 'max' if monitoring accuracy, 'min' if monitoring loss
        verbose=1
    )

    # Compile the model with the custom optimizer
    model2.compile(optimizer=custom_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    fitted_model2 = model2.fit(train_generator_shuffle, epochs=params['epochs'], validation_data=test_generator, callbacks=[model_checkpoint_callback])

    # Load the best model from the saved checkpoint file
    model2 = models.load_model(checkpoint_filepath)
   
    # Print model evaluation
    print_evaluation(model2, train_generator, test_generator, val_generator)
    
    # Plot model evaluation
    plot_evaluation(fitted_model2)
# Out:
# Found 791 images belonging to 2 classes.
# Found 791 images belonging to 2 classes.
# Found 114 images belonging to 2 classes.
# Found 95 images belonging to 2 classes.
# Epoch 1/25
# 25/25 [==============================] - ETA: 0s - loss: 0.7408 - accuracy: 0.5133
# Epoch 1: val_accuracy improved from -inf to 0.66667, saving model to results/best_model_mobilenetv2.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 57s 337ms/step - loss: 0.7408 - accuracy: 0.5133 - val_loss: 0.6065 - val_accuracy: 0.6667
# Epoch 2/25
# 25/25 [==============================] - ETA: 0s - loss: 0.7079 - accuracy: 0.5651
# Epoch 2: val_accuracy improved from 0.66667 to 0.69298, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 7s 271ms/step - loss: 0.7079 - accuracy: 0.5651 - val_loss: 0.5979 - val_accuracy: 0.6930
# Epoch 3/25
# 25/25 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.5853
# Epoch 3: val_accuracy improved from 0.69298 to 0.70175, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 241ms/step - loss: 0.6713 - accuracy: 0.5853 - val_loss: 0.5900 - val_accuracy: 0.7018
# Epoch 4/25
# 25/25 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.6498
# Epoch 4: val_accuracy improved from 0.70175 to 0.71930, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 244ms/step - loss: 0.6341 - accuracy: 0.6498 - val_loss: 0.5821 - val_accuracy: 0.7193
# Epoch 5/25
# 25/25 [==============================] - ETA: 0s - loss: 0.6082 - accuracy: 0.6877
# Epoch 5: val_accuracy improved from 0.71930 to 0.73684, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 234ms/step - loss: 0.6082 - accuracy: 0.6877 - val_loss: 0.5747 - val_accuracy: 0.7368
# Epoch 6/25
# 25/25 [==============================] - ETA: 0s - loss: 0.5853 - accuracy: 0.7092
# Epoch 6: val_accuracy improved from 0.73684 to 0.74561, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 238ms/step - loss: 0.5853 - accuracy: 0.7092 - val_loss: 0.5667 - val_accuracy: 0.7456
# Epoch 7/25
# 25/25 [==============================] - ETA: 0s - loss: 0.5537 - accuracy: 0.7358
# Epoch 7: val_accuracy improved from 0.74561 to 0.76316, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 222ms/step - loss: 0.5537 - accuracy: 0.7358 - val_loss: 0.5605 - val_accuracy: 0.7632
# Epoch 8/25
# 25/25 [==============================] - ETA: 0s - loss: 0.5336 - accuracy: 0.7636
# Epoch 8: val_accuracy did not improve from 0.76316
# 25/25 [==============================] - 5s 202ms/step - loss: 0.5336 - accuracy: 0.7636 - val_loss: 0.5539 - val_accuracy: 0.7632
# Epoch 9/25
# 25/25 [==============================] - ETA: 0s - loss: 0.5178 - accuracy: 0.7952
# Epoch 9: val_accuracy improved from 0.76316 to 0.77193, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 8s 304ms/step - loss: 0.5178 - accuracy: 0.7952 - val_loss: 0.5489 - val_accuracy: 0.7719
# Epoch 10/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4789 - accuracy: 0.8180
# Epoch 10: val_accuracy improved from 0.77193 to 0.78070, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 229ms/step - loss: 0.4789 - accuracy: 0.8180 - val_loss: 0.5438 - val_accuracy: 0.7807
# Epoch 11/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4713 - accuracy: 0.8180
# Epoch 11: val_accuracy did not improve from 0.78070
# 25/25 [==============================] - 5s 201ms/step - loss: 0.4713 - accuracy: 0.8180 - val_loss: 0.5405 - val_accuracy: 0.7807
# Epoch 12/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.8331
# Epoch 12: val_accuracy improved from 0.78070 to 0.79825, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 227ms/step - loss: 0.4511 - accuracy: 0.8331 - val_loss: 0.5384 - val_accuracy: 0.7982
# Epoch 13/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.8458
# Epoch 13: val_accuracy improved from 0.79825 to 0.81579, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 226ms/step - loss: 0.4428 - accuracy: 0.8458 - val_loss: 0.5372 - val_accuracy: 0.8158
# Epoch 14/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4231 - accuracy: 0.8673
# Epoch 14: val_accuracy improved from 0.81579 to 0.82456, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 226ms/step - loss: 0.4231 - accuracy: 0.8673 - val_loss: 0.5358 - val_accuracy: 0.8246
# Epoch 15/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4091 - accuracy: 0.8571
# Epoch 15: val_accuracy improved from 0.82456 to 0.84211, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 231ms/step - loss: 0.4091 - accuracy: 0.8571 - val_loss: 0.5350 - val_accuracy: 0.8421
# Epoch 16/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8812
# Epoch 16: val_accuracy did not improve from 0.84211
# 25/25 [==============================] - 5s 210ms/step - loss: 0.3907 - accuracy: 0.8812 - val_loss: 0.5357 - val_accuracy: 0.8421
# Epoch 17/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.8723
# Epoch 17: val_accuracy did not improve from 0.84211
# 25/25 [==============================] - 5s 191ms/step - loss: 0.3867 - accuracy: 0.8723 - val_loss: 0.5364 - val_accuracy: 0.8421
# Epoch 18/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3719 - accuracy: 0.8812
# Epoch 18: val_accuracy did not improve from 0.84211
# 25/25 [==============================] - 5s 199ms/step - loss: 0.3719 - accuracy: 0.8812 - val_loss: 0.5379 - val_accuracy: 0.8421
# Epoch 19/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.9102
# Epoch 19: val_accuracy improved from 0.84211 to 0.85965, saving model to results/best_model_mobilenetv2.h5
# 25/25 [==============================] - 6s 239ms/step - loss: 0.3537 - accuracy: 0.9102 - val_loss: 0.5399 - val_accuracy: 0.8596
# Epoch 20/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.9014
# Epoch 20: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 5s 205ms/step - loss: 0.3409 - accuracy: 0.9014 - val_loss: 0.5412 - val_accuracy: 0.8596
# Epoch 21/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3425 - accuracy: 0.9064
# Epoch 21: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 5s 201ms/step - loss: 0.3425 - accuracy: 0.9064 - val_loss: 0.5449 - val_accuracy: 0.8596
# Epoch 22/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3301 - accuracy: 0.9027
# Epoch 22: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 5s 197ms/step - loss: 0.3301 - accuracy: 0.9027 - val_loss: 0.5487 - val_accuracy: 0.8596
# Epoch 23/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.9267
# Epoch 23: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 5s 195ms/step - loss: 0.3159 - accuracy: 0.9267 - val_loss: 0.5527 - val_accuracy: 0.8509
# Epoch 24/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.9166
# Epoch 24: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 5s 198ms/step - loss: 0.3099 - accuracy: 0.9166 - val_loss: 0.5575 - val_accuracy: 0.8509
# Epoch 25/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2940 - accuracy: 0.9279
# Epoch 25: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 5s 201ms/step - loss: 0.2940 - accuracy: 0.9279 - val_loss: 0.5629 - val_accuracy: 0.8421
#
#  * Evaluation for Model 1 (Simple Convolutional Neural Network (CNN)):
# 25/25 [==============================] - 6s 161ms/step
#
#  * Confusion_matrix (TRAIN):
# [[342  52]
#  [141 256]]
#
#  * Classification_report (TRAIN):
#               precision    recall  f1-score   support
#
#            0       0.71      0.87      0.78       394
#            1       0.83      0.64      0.73       397
#
#     accuracy                           0.76       791
#    macro avg       0.77      0.76      0.75       791
# weighted avg       0.77      0.76      0.75       791
#
# 4/4 [==============================] - 1s 131ms/step
#
#  * Confusion_matrix (TEST):
# [[55  3]
#  [13 43]]
#
#  * Classification_report (TEST):
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87        58
#            1       0.93      0.77      0.84        56
#
#     accuracy                           0.86       114
#    macro avg       0.87      0.86      0.86       114
# weighted avg       0.87      0.86      0.86       114
#
# 3/3 [==============================] - 1s 152ms/step
#
#  * Confusion_matrix (VAL):
# [[39  9]
#  [ 8 39]]
#
#  * Classification_report (VAL):
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82        48
#            1       0.81      0.83      0.82        47
#
#     accuracy                           0.82        95
#    macro avg       0.82      0.82      0.82        95
# weighted avg       0.82      0.82      0.82        95

# %% [markdown]
# ### Custom CNN with Dropout

# %%
checkpoint_filepath = 'results/best_model_cnn_dropout.h5'
custom_learning_rate = 0.00001

# Define data generators for training and testing sets
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator_shuffle = train_datagen.flow_from_directory(
    params['data'] + '/train',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=True,
)

train_generator = train_datagen.flow_from_directory(
    params['data'] + '/train',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

test_generator = test_datagen.flow_from_directory(
    params['data'] + '/test',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

val_generator = val_datagen.flow_from_directory(
    params['data'] + '/val',
    target_size=(img_height, img_width),
    batch_size=params['batch'],
    class_mode='binary',
    shuffle=False,
)

with strategy.scope():
    # Model 3: Custom CNN with Dropout
    model3 = models.Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.25),
        layers.Dense(1, activation='sigmoid')
    ])

    # Create an optimizer with the custom learning rate
    custom_optimizer = Adam(learning_rate=custom_learning_rate)

    # Define a ModelCheckpoint callback to save the best model
    model_checkpoint_callback = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_best_only=True,
        monitor='val_accuracy',  # You can change this to 'val_accuracy' or another metric
        mode='max',          # Set to 'max' if monitoring accuracy, 'min' if monitoring loss
        verbose=1
    )

    # Compile the model with the custom optimizer
    model3.compile(optimizer=custom_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    fitted_model3 = model3.fit(train_generator_shuffle, epochs=params['epochs'], validation_data=test_generator, callbacks=[model_checkpoint_callback])

    # Load the best model from the saved checkpoint file
    model3 = models.load_model(checkpoint_filepath)

    # Print model evaluation
    print_evaluation(model3, train_generator, test_generator, val_generator)
    
    # Plot model evaluation
    plot_evaluation(fitted_model3)
# Out:
# Found 791 images belonging to 2 classes.
# Found 791 images belonging to 2 classes.
# Found 114 images belonging to 2 classes.
# Found 95 images belonging to 2 classes.
# Epoch 1/25
# 2024-01-14 10:30:03.629652: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_9/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 25/25 [==============================] - ETA: 0s - loss: 0.7122 - accuracy: 0.6397
# Epoch 1: val_accuracy improved from -inf to 0.52632, saving model to results/best_model_cnn_dropout.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 26s 931ms/step - loss: 0.7122 - accuracy: 0.6397 - val_loss: 0.6172 - val_accuracy: 0.5263
# Epoch 2/25
# 25/25 [==============================] - ETA: 0s - loss: 0.4460 - accuracy: 0.8003
# Epoch 2: val_accuracy improved from 0.52632 to 0.81579, saving model to results/best_model_cnn_dropout.h5
# 25/25 [==============================] - 22s 889ms/step - loss: 0.4460 - accuracy: 0.8003 - val_loss: 0.5492 - val_accuracy: 0.8158
# Epoch 3/25
# 25/25 [==============================] - ETA: 0s - loss: 0.3299 - accuracy: 0.8812
# Epoch 3: val_accuracy did not improve from 0.81579
# 25/25 [==============================] - 16s 612ms/step - loss: 0.3299 - accuracy: 0.8812 - val_loss: 0.5520 - val_accuracy: 0.7719
# Epoch 4/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.9115
# Epoch 4: val_accuracy did not improve from 0.81579
# 25/25 [==============================] - 16s 611ms/step - loss: 0.2788 - accuracy: 0.9115 - val_loss: 0.5252 - val_accuracy: 0.7895
# Epoch 5/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9216
# Epoch 5: val_accuracy did not improve from 0.81579
# 25/25 [==============================] - 18s 698ms/step - loss: 0.2362 - accuracy: 0.9216 - val_loss: 0.5252 - val_accuracy: 0.7456
# Epoch 6/25
# 25/25 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9229
# Epoch 6: val_accuracy did not improve from 0.81579
# 25/25 [==============================] - 16s 627ms/step - loss: 0.2262 - accuracy: 0.9229 - val_loss: 0.4716 - val_accuracy: 0.8070
# Epoch 7/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9558
# Epoch 7: val_accuracy did not improve from 0.81579
# 25/25 [==============================] - 16s 622ms/step - loss: 0.1841 - accuracy: 0.9558 - val_loss: 0.4717 - val_accuracy: 0.8158
# Epoch 8/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1619 - accuracy: 0.9545
# Epoch 8: val_accuracy improved from 0.81579 to 0.85965, saving model to results/best_model_cnn_dropout.h5
# 25/25 [==============================] - 22s 900ms/step - loss: 0.1619 - accuracy: 0.9545 - val_loss: 0.4615 - val_accuracy: 0.8596
# Epoch 9/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9671
# Epoch 9: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 16s 618ms/step - loss: 0.1454 - accuracy: 0.9671 - val_loss: 0.4580 - val_accuracy: 0.8509
# Epoch 10/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9697
# Epoch 10: val_accuracy did not improve from 0.85965
# 25/25 [==============================] - 16s 615ms/step - loss: 0.1478 - accuracy: 0.9697 - val_loss: 0.4744 - val_accuracy: 0.8509
# Epoch 11/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9722
# Epoch 11: val_accuracy improved from 0.85965 to 0.86842, saving model to results/best_model_cnn_dropout.h5
# 25/25 [==============================] - 22s 883ms/step - loss: 0.1244 - accuracy: 0.9722 - val_loss: 0.4721 - val_accuracy: 0.8684
# Epoch 12/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9697
# Epoch 12: val_accuracy did not improve from 0.86842
# 25/25 [==============================] - 16s 625ms/step - loss: 0.1216 - accuracy: 0.9697 - val_loss: 0.4219 - val_accuracy: 0.8684
# Epoch 13/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9747
# Epoch 13: val_accuracy did not improve from 0.86842
# 25/25 [==============================] - 16s 615ms/step - loss: 0.1149 - accuracy: 0.9747 - val_loss: 0.4238 - val_accuracy: 0.8333
# Epoch 14/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9735
# Epoch 14: val_accuracy did not improve from 0.86842
# 25/25 [==============================] - 16s 625ms/step - loss: 0.0984 - accuracy: 0.9735 - val_loss: 0.4090 - val_accuracy: 0.8684
# Epoch 15/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0935 - accuracy: 0.9798
# Epoch 15: val_accuracy did not improve from 0.86842
# 25/25 [==============================] - 16s 627ms/step - loss: 0.0935 - accuracy: 0.9798 - val_loss: 0.4069 - val_accuracy: 0.8596
# Epoch 16/25
# 25/25 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9785
# Epoch 16: val_accuracy did not improve from 0.86842
# 25/25 [==============================] - 16s 621ms/step - loss: 0.1010 - accuracy: 0.9785 - val_loss: 0.4182 - val_accuracy: 0.8684
# Epoch 17/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9735
# Epoch 17: val_accuracy did not improve from 0.86842
# 25/25 [==============================] - 16s 619ms/step - loss: 0.0924 - accuracy: 0.9735 - val_loss: 0.4142 - val_accuracy: 0.8596
# Epoch 18/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9785
# Epoch 18: val_accuracy improved from 0.86842 to 0.87719, saving model to results/best_model_cnn_dropout.h5
# 25/25 [==============================] - 22s 887ms/step - loss: 0.0832 - accuracy: 0.9785 - val_loss: 0.4508 - val_accuracy: 0.8772
# Epoch 19/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9861
# Epoch 19: val_accuracy did not improve from 0.87719
# 25/25 [==============================] - 17s 651ms/step - loss: 0.0727 - accuracy: 0.9861 - val_loss: 0.4052 - val_accuracy: 0.8684
# Epoch 20/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9785
# Epoch 20: val_accuracy did not improve from 0.87719
# 25/25 [==============================] - 15s 604ms/step - loss: 0.0738 - accuracy: 0.9785 - val_loss: 0.4464 - val_accuracy: 0.8509
# Epoch 21/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9836
# Epoch 21: val_accuracy did not improve from 0.87719
# 25/25 [==============================] - 16s 625ms/step - loss: 0.0713 - accuracy: 0.9836 - val_loss: 0.4086 - val_accuracy: 0.8509
# Epoch 22/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9861
# Epoch 22: val_accuracy did not improve from 0.87719
# 25/25 [==============================] - 16s 613ms/step - loss: 0.0594 - accuracy: 0.9861 - val_loss: 0.3918 - val_accuracy: 0.8596
# Epoch 23/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9861
# Epoch 23: val_accuracy did not improve from 0.87719
# 25/25 [==============================] - 16s 619ms/step - loss: 0.0576 - accuracy: 0.9861 - val_loss: 0.3941 - val_accuracy: 0.8421
# Epoch 24/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9874
# Epoch 24: val_accuracy did not improve from 0.87719
# 25/25 [==============================] - 16s 617ms/step - loss: 0.0573 - accuracy: 0.9874 - val_loss: 0.4530 - val_accuracy: 0.8333
# Epoch 25/25
# 25/25 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9886
# Epoch 25: val_accuracy did not improve from 0.87719
# 25/25 [==============================] - 16s 621ms/step - loss: 0.0587 - accuracy: 0.9886 - val_loss: 0.4259 - val_accuracy: 0.8772
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[14], line 70
#      67 fitted_model3 = model3.fit(train_generator_shuffle, epochs=params['epochs'], validation_data=test_generator, callbacks=[model_checkpoint_callback])
#      69 # Load the best model from the saved checkpoint file
# ---> 70 model3 = models.load_model(checkpoint_filepath)
#      72 # Print model evaluation
#      73 print_evaluation(model3, train_generator, test_generator, val_generator)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_api.py:238, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     230     return saving_lib.load_model(
#     231         filepath,
#     232         custom_objects=custom_objects,
#     233         compile=compile,
#     234         safe_mode=safe_mode,
#     235     )
#     237 # Legacy case.
# --> 238 return legacy_sm_saving_lib.load_model(
#     239     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     240 )
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:98, in convert_to_eager_tensor(value, ctx, dtype)
#      96     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97 ctx.ensure_initialized()
# ---> 98 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
